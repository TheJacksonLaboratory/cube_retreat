# %% [markdown]
# # Mice Data
# Individual mice data

# %%
library(cubeR)
data <- cubeR::cubeR(c("Mice"))
head(data, 5)
# Out:
# [1] "dataset:  Mice"
#   mouseid    jumusid other climbid dateofbirth diet       datediet
# 1 mouseid    jumusid other climbid dateofbirth diet       datediet
# 2 JAXMM00063 JMUS63  DO021 N/A     5/29/2014   JAXDI00001 6/30/2014
# 3 JAXMM00064 JMUS64  DO022 N/A     5/29/2014   JAXDI00001 6/30/2014
# 4 JAXMM00065 JMUS65  DO023 N/A     5/29/2014   JAXDI00001 6/30/2014
# 5 JAXMM00066 JMUS66  DO024 N/A     5/29/2014   JAXDI00001 6/30/2014
#   drugtreatment datedrugstarted sex    comment
# 1 drugtreatment datedrugstarted sex    comment
# 2 JAXDR00002    N/A             female Sample sent from Keller Attie as RNA
# 3 JAXDR00002    N/A             female Sample sent from Keller Attie as RNA
# 4 JAXDR00002    N/A             female Sample sent from Keller Attie as RNA
# 5 JAXDR00002    N/A             female Sample sent from Keller Attie as RNA
#   partofcohort study                        strain   partofstudy
# 1 partofcohort study                        strain   partofstudy
# ...

# %%
help(mice)
# Out:
# Cube Metadata Individual Mice      package:cubeR       R Documentation
#
# e
#
# n:
#
#      Metadata information for Individual Mice
#
# e:
#
#      mice
#
# t:
#
#      A Disease metadata with 15 variables:
#
#      mouseid mouse id
#
#      jumusid jumus id
#
#      other other
#
#      climbid climb id
#
#      dateofbirth date of birth
#
#      diet diet
#
#      datediet date diet
#
#      drugtreatment drug treatment
#
#      datedrugstarted date drug started
#
#      sex sex
#
#      comment comment
#
#      partofcohort part of cohort
#
#      study study
#
#      strain strain
#
#      partofstudy part of study
