# %% [markdown]
# # Assay Data
# Cube Assay metadata

# %%
library(cubeR)
data <- cubeR::cubeR(c("Assay"))
data
# Out:
# [1] "dataset:  Assay"
# [1] "accession_ids:  JAXAS00005"
#    accession_id subclass    target       seqclass                antibodies
# 1  JAXAS00001   bead array  naked gDNA   N/A                     no
# 2  JAXAS00002   sequencing  chromatin    Open Chromatin          no
# 3  JAXAS00003   anatomical  organism     N/A                     no
# 4  JAXAS00004   behavioural organism     N/A                     no
# 5  JAXAS00005   behavioural organism     N/A                     no
# 6  JAXAS00006   metabolic   metabolite   N/A                     no
# 7  JAXAS00007   anatomical  organism     N/A                     no
# 8  JAXAS00008   sequencing  bead array   naked RNA               RNA Seq
# 9  JAXAS00009   metabolic
# 10 JAXAS00010   metabolic
# 11 JAXAS00011   microscopy  tissue       N/A                     yes
# 12 JAXAS00012   microscopy  tissue       N/A                     sometimes
# 13 JAXAS00013   sequencing  naked RNA    cDNA/EST                no
# ...

# %%
help(assay)
# Out:
# Cube Metadata Assay           package:cubeR            R Documentation
#
# y
#
# n:
#
#      Metadata information for assay
#
# e:
#
#      assay
#
# t:
#
#      A assay metadata with 5 variables:
#
#      accession_id accession id
#
#      subclass Sub class
#
#      target Target
#
#      seqclass Seq class
#
#      short Short
