# %% [markdown]
# # Mouse Strain Data
# Mouse strain data

# %%
library(cubeR)
data <- cubeR::cubeR(c("Mouse_Strain"))
data
# Out:
# [1] "dataset:  Mouse_Strain"
# [1] "accession_ids:  JAXAS00005"
#    accession_id strain_name       classification
# 1  JAXMS00001   C57BL/6J          Inbred - Founder
# 2  JAXMS00002   CAST/EiJ          Inbred - Founder
# 3  JAXMS00003   A/J               Inbred - Founder
# 4  JAXMS00004   WSB/EiJ           Inbred - Founder
# 5  JAXMS00005   NOD/ShILtJ        Inbred - Founder
# 6  JAXMS00006   129S1/SvImJ       Inbred - Founder
# 7  JAXMS00007   DO (J:DO)         Diversity Outbred
# 8  JAXMS00008   RIX:CC(011 X 027) Collaborative Cross F1 hybrid
# 9  JAXMS00009   RIX:CC(011 X 005) Collaborative Cross F1 hybrid
# 10 JAXMS00010   RIX:CC(002 X 043) Collaborative Cross F1 hybrid
# 11 JAXMS00011   RIX:CC(030 X 002) Collaborative Cross F1 hybrid
# 12 JAXMS00012   RIX:CC(002 X 075) Collaborative Cross F1 hybrid
# 13 JAXMS00013   RIX:CC(024 X 002) Collaborative Cross F1 hybrid
# 14 JAXMS00014   RIX:CC(012 X 002) Collaborative Cross F1 hybrid
# ...

# %%
help(mouse_strain)
# Out:
# Cube Metadata Mouse_Strain        package:cubeR        R Documentation
#
# n
#
# n:
#
#      Metadata information for Mouse_Strain
#
# e:
#
#      mouse_strain
#
# t:
#
#      A Disease metadata with 3 variables:
#
#      accession_id accession id
#
#      strain_name strain_name
#
#      classification classification
