# %% [markdown]
# # Cube Custom R Package
# This is the notebook to develop cube custom package.  All the package is in "/home/jupypter/cubeR" directory, and pushed to git
# https://github.com/TheJacksonLaboratory/cubeR
# for release.
#
# The package follow the directory structure by these tutorals:
# * http://r-pkgs.had.co.nz/intro.html
# * https://hilaryparker.com/2014/04/29/writing-an-r-package-from-scratch/
# * https://tinyheero.github.io/jekyll/update/2015/07/26/making-your-first-R-package.html
#
# To release
# * run
# ```
# setwd("./cubeR")
# document()
# ```
# * git push to repo

# %%
install.packages("devtools")
library("devtools")
devtools::install_github("klutometis/roxygen")
library(roxygen2)

setwd("/home/jupyter/cubeR")

# %%
setwd("/home/jupyter/cubeR/cubeR")
# need to figure out auto build 
snp_data <- read.csv("data-raw/snap_grid_sample.csv")
usethis::use_data(snp_data, overwrite = TRUE)

assay <- read.csv("data-raw/assay.csv")
usethis::use_data(assay, overwrite = TRUE)

disease <- read.csv("data-raw/disease.csv")
usethis::use_data(disease, overwrite = TRUE)

drug_treatment <- read.csv("data-raw/drug_treatment.csv")
usethis::use_data(drug_treatment, overwrite = TRUE)

mouse_strain <- read.csv("data-raw/mouse_strain.csv")
usethis::use_data(mouse_strain, overwrite = TRUE)

mice <- read.csv("data-raw/mice.csv")
usethis::use_data(mice, overwrite = TRUE)

document()
usethis::use_vignette("introduction")
# Out:
# ✔ Setting active project to '/home/jupyter/cubeR/cubeR'
#
# ✔ Saving 'snp_data' to 'data/snp_data.rda'
#
# ● Document your data (see 'https://r-pkgs.org/data.html')
#
# ✔ Saving 'assay' to 'data/assay.rda'
#
# ● Document your data (see 'https://r-pkgs.org/data.html')
#
# ✔ Saving 'disease' to 'data/disease.rda'
#
# ● Document your data (see 'https://r-pkgs.org/data.html')
#
# ✔ Saving 'drug_treatment' to 'data/drug_treatment.rda'
#
# ● Document your data (see 'https://r-pkgs.org/data.html')
#
# ✔ Saving 'mouse_strain' to 'data/mouse_strain.rda'
#
# ● Document your data (see 'https://r-pkgs.org/data.html')
#
# ✔ Saving 'mice' to 'data/mice.rda'
#
# ● Document your data (see 'https://r-pkgs.org/data.html')
#
# Updating cubeR documentation
#
# Loading cubeR
#
# Warning message:
# “[/home/jupyter/cubeR/cubeR/R/hello.R:4] @param requires name and description”
# Writing NAMESPACE
# Writing NAMESPACE
# Writing Cube-Metadata-Individual-Mice.Rd
# ✔ Leaving 'vignettes/introduction.Rmd' unchanged

# %%
setwd("/home/jupyter/cubeR")
install("cubeR")
# Out:
# ✔  checking for file ‘/home/jupyter/cubeR/cubeR/DESCRIPTION’
# ─  preparing ‘cubeR’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  looking to see if a ‘data/datalist’ file should be added
# ─  building ‘cubeR_0.0.0.9000.tar.gz’
#
# Running /usr/lib/R/bin/R CMD INSTALL /tmp/RtmpfdVCuw/cubeR_0.0.0.9000.tar.gz \
#   --install-tests
# * installing to library ‘/usr/local/lib/R/site-library’
# * installing *source* package ‘cubeR’ ...
# ** using staged installation
# ** R
# ** data
# *** moving datasets to lazyload DB
# ** inst
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** installing vignettes
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (cubeR)

# %%
library(cubeR)
cubeR('Assay')

# %%
help(mice)
# Out:
# Cube Metadata Individual Mice      package:cubeR       R Documentation
#
# e
#
# n:
#
#      Metadata information for Individual Mice
#
# e:
#
#      mice
#
# t:
#
#      A Disease metadata with 15 variables:
#
#      mouseid mouse id
#
#      jumusid jumus id
#
#      other other
#
#      climbid climb id
#
#      dateofbirth date of birth
#
#      diet diet
#
#      datediet date diet
#
#      drugtreatment drug treatment
#
#      datedrugstarted date drug started
#
#      sex sex
#
#      comment comment
#
#      partofcohort part of cohort
#
#      study study
#
#      strain strain
#
#      partofstudy part of study

# %%
print(ncol(snp_data))
print(nrow(snp_data))

head(metadata-assay, 6)
# lapply(snp_data, mean, na.rm = TRUE)

# %%
row <- subset(snp_data, start_position=='110002640' && strain_name == "129P2/OlaHsd:129P2/OlaHsd" )
print(row)
